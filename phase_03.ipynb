# %% [markdown]
# ## advanced operations with business examples

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
# Data structure: [restaurant_id, 2021, 2022, 2023, 2024]
sales_data = np.array([
    [1, 150000, 180000, 220000, 110000],  # Paradise Biryani
    [2, 120000, 140000, 160000, 190000],  # Beijing Bites
    [3, 200000, 230000, 260000, 300000],  # Pizza Hub
    [4, 180000, 210000, 240000, 270000],  # Burger Point
    [5, 160000, 185000, 205000, 230000]   # Chai Point
])

print("-------- zomato sales analysis --------")

print("\nsales data shape: ", sales_data.shape)

# print("\nsample data for 1st 3 restaurants: \n", sales_data[0:3]) --> both syntax are correct..!
print("\nsample data for 1st 3 restaurants: \n", sales_data[:3])
# Out:
# -------- zomato sales analysis --------
#
# sales data shape:  (5, 5)
#
# sample data for 1st 3 restaurants:
#  [[     1 150000 180000 220000 110000]
#  [     2 120000 140000 160000 190000]
#  [     3 200000 230000 260000 300000]]

# %%
# total sales per year

print(np.sum(sales_data, axis=0))


yearly_total = np.sum(sales_data[:, 1:], axis=0)
print("yearly total: ", yearly_total)


# minimum sales per restaurant
min_sales = np.min(sales_data[:, 1:], axis=1)
print("min sales per restaurant: ", min_sales)

# maximum sales per year
max_sales = np.max(sales_data[:, 1:], axis=1)
print("max sales per restaurant: ", max_sales)

# average sales per restaurant
avg_sales = np.mean(sales_data[:, 1:], axis = 1)
print("average sales per restaurant: ", avg_sales)
# Out:
# [     15  810000  945000 1085000 1100000]
# yearly total:  [ 810000  945000 1085000 1100000]
# min sales per restaurant:  [110000 120000 200000 180000 160000]
# max sales per restaurant:  [220000 190000 300000 270000 230000]
# average sales per restaurant:  [165000. 152500. 247500. 225000. 195000.]

# %%
cumulative_sum = np.cumsum(sales_data[:, 1:], axis=1)
print("cumulative sum: \n", cumulative_sum)


# matplotlib
plt.figure(figsize=(8, 6))
plt.plot(np.mean(cumulative_sum, axis=0))
plt.title("average cumulative sales per year across all restaurants")
plt.xlabel("years")
plt.ylabel("sales")
plt.grid(True)
plt.show()
# Out:
# cumulative sum:
#  [[150000 330000 550000 660000]
#  [120000 260000 420000 610000]
#  [200000 430000 690000 990000]
#  [180000 390000 630000 900000]
#  [160000 345000 550000 780000]]

# %% [markdown]
# ---
# ### vector operations

# %%
vector1 = np.array([1, 2, 3, 4, 5])
vector2 = np.array([6, 7, 8, 9, 10])

print("vector addition: ", vector1 + vector2)

print("\nmultiplication of vectors : ", vector1 * vector2)

print("\ndot product of vectors : ", np.dot(vector1, vector2))

angle = np.arccos((np.dot(vector1, vector2)) / (np.linalg.norm(vector1) * np.linalg.norm(vector2)))
print("\nangle: ", angle)
# Out:
# vector addition:  [ 7  9 11 13 15]
#
# multiplication of vectors :  [ 6 14 24 36 50]
#
# dot product of vectors :  130
#
# angle:  0.26554161733900966

# %%
restaurant_types = np.array(['biryani', 'chinese', 'pizza', 'burger', 'cafe'])

vectorized_upper = np.vectorize(str.upper)

print("vectorized upper: ", vectorized_upper(restaurant_types))
# Out:
# vectorized upper:  ['BIRYANI' 'CHINESE' 'PIZZA' 'BURGER' 'CAFE']

# %%
monthly_avg = sales_data[:, 1:] / 12
print(monthly_avg)
# Out:
# [[12500.         15000.         18333.33333333  9166.66666667]
#  [10000.         11666.66666667 13333.33333333 15833.33333333]
#  [16666.66666667 19166.66666667 21666.66666667 25000.        ]
#  [15000.         17500.         20000.         22500.        ]
#  [13333.33333333 15416.66666667 17083.33333333 19166.66666667]]
